# %% [markdown]
# ## Installing Transformers and Sentencepiece

# %%
#install transformes 
# !pip install transformers
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 32.1 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.1)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 12.2 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 63.8 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 54.4 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.8.1 pyyaml-6.0 tokenizers-0.12.1 transformers-4.20.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 34.1 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.96

# %% [markdown]
# ## Necessary imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch
from transformers import AutoTokenizer, XLMRobertaForSequenceClassification, AdamW, get_linear_schedule_with_warmup, get_scheduler
from torch.utils.data import TensorDataset, random_split, DataLoader, RandomSampler, SequentialSampler
import random
from tqdm.auto import tqdm

# %% [markdown]
# ## 2.1 - Installing UrduTweets Dataset (GitHub)
#
# Source: https://github.com/zarmeen92/urdutweets
#
# Total Instances: 3731
#
# Summary: The dataset consists of 3103  tweets, polarity, cleaned tweet, and sentiment_score. The polarity represents the label of the tweet either as O (for neutral), P(for positive), N (for negative). The data seems to be accurately labelled by using the score technique after manually checking it. It is mostly based on but not entirely on tweets related to politics bulletin.
#
# Validity: The dataset has been used by students of IBA and used in paper - https://www.researchgate.net/publication/343667083_Sentiment_Analysis_on_Urdu_Tweets_Using_Markov_Chains.

# %%
# !git clone https://github.com/zarmeen92/urdutweets.git
# Out:
# Cloning into 'urdutweets'...
# remote: Enumerating objects: 3, done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 3
# Unpacking objects: 100% (3/3), done.

# %%
d2 = pd.read_csv("/content/urdutweets/urdutweets.csv", encoding='utf-8', delimiter='\t', skip_blank_lines=True)
d2 = d2.filter(['cleanTweet', 'Polarity'])
d2["Polarity"].replace(['P', 'N', 'O'], [0, 1, 2], inplace=True) # formatting sentiment lablelling
d2.rename(columns={"cleanTweet": "Text", "Polarity": "Sentiment"}, inplace=True) # renaming column to ensure same format of all datasets
d2 = d2.dropna()
d2 = d2.reset_index()

d2
# Out:
#       index                                               Text  Sentiment
# 0         0  رائيونڈ ميں ہنگامي اجلاس شہباز شريف ليے بيڈ تر...          2
# 1         1  سانحہ ماڈل ٹاؤن باقر نجفي رپورٹ خاص صفحے منظرع...          2
# 2         2  اسلام آباد جلسہ ميں پي پي جيالوں درميان کرسياں...          1
# 3         3                    کيا رپورٹ کچھ حصے حذف نہيں گئے؟          2
# 4         4  نوازشريف،مريم نوازاورکيپٹن ريٹائرڈصفدر کےخلاف ...          2
# ...     ...                                                ...        ...
# 3723   3726  انا للہ وانا الیہ راجعون۔ اللہ آپکی والدہ جنت ...          2
# 3724   3727  بادام زیادہ کھا بیٹھا ہوں\nکوئ بتاو فالتو عقل ...          1
# 3725   3728  کبھی کبھی خاموش رہنا پڑتا منظرِعام غائب ہونا پ...          1
# 3726   3729                      بادام ساتھ مجھے کھا جائیں گے🙄          1
# 3727   3730  جن لباس سرِ رہ سیاہی لکھی گئی\nیہی داغ سجا سرِ...          1
#
# [3728 rows x 3 columns]

# %% [markdown]
# ## 2.2 - Visualizing the data of Dataset 2

# %%
y = list(d2["Sentiment"].value_counts()) # getting frequency of all the 2 sentiments
plt.plot()
plt.bar(["Positive", "Negative", "Neutral"], y) # plottign frequency against labels in a bar chart
plt.xlabel("Sentiment POS/NEG/NEU")
plt.ylabel("Frequency")
plt.title("Sentiment frequency of all Urdu Datasets")
plt.show()

print("Positive {}, Negative {}, Neutral {}".format(y[0], y[1], y[2]))
# Out:
# Positive 1911, Negative 1407, Neutral 410

# %% [markdown]
# ## Importing Tokenizer

# %%
# Download the tokenizer for the XLM-Robert `base` model.
xlmr_tokenizer = AutoTokenizer.from_pretrained("xlm-roberta-base")
# Out:
# Downloading:   0%|          | 0.00/615 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/8.68M [00:00<?, ?B/s]

# %% [markdown]
# ## Sample tokenization of text (and checking data)

# %%
#xlmr_tokenizer creates tokens based on subword
print("sample text = ", d2.Text[1])
tokens = xlmr_tokenizer.tokenize(d2.Text[1])
print("XLMR Roberta covert sample text into following tokens \n ", tokens)
# Out:
# sample text =  سانحہ ماڈل ٹاؤن باقر نجفي رپورٹ خاص صفحے منظرعام آگئے
# XLMR Roberta covert sample text into following tokens
#   ['▁سان', 'ح', 'ہ', '▁ماڈل', '▁ٹاؤن', '▁باقر', '▁نجف', 'ي', '▁رپورٹ', '▁خاص', '▁صفح', 'ے', '▁منظر', 'عام', '▁آگ', 'ئے']

# %%
#some samples from data frame
print(d2.Text[1])
print(d2.Text[2])
print(d2.Text[3])
# Out:
# سانحہ ماڈل ٹاؤن باقر نجفي رپورٹ خاص صفحے منظرعام آگئے
# اسلام آباد جلسہ ميں پي پي جيالوں درميان کرسياں چل گئيں متعدد زخمي …
# کيا رپورٹ کچھ حصے حذف نہيں گئے؟

# %%
#checking the sentiment values 
#later on we will convert them into categorie i.e, integers
d2['Sentiment']
# Out:
# 0       2
# 1       2
# 2       1
# 3       2
# 4       2
#        ..
# 3723    2
# 3724    1
# 3725    1
# 3726    1
# 3727    1
# Name: Sentiment, Length: 3728, dtype: int64

# %%
#accessing the sentiments for first few samples 
print(d2.at[0,'Sentiment'])
print(d2.at[1,'Sentiment'])
print(d2.at[2,'Sentiment'])
# Out:
# 2
# 2
# 1

# %% [markdown]
# ## ***Encoding all samples while varying the max_length hyperparameter***

# %% [markdown]
# ## 1. First run:
#     - Hyperparameters:
#         - max_length = 50
#         - epochs = 5
#         - batch_size = 16

# %%
labels_ur = []
input_ids_ur = []
attn_masks_ur= []

print("Encoding all Examples in the dataset \n" )

for ind in d2.index:
  text = d2.Text[ind]
  #convert sentence pairs to input ids, with attention masks
  
  encoded_dict = xlmr_tokenizer.encode_plus(text,max_length = 50,  
                                       padding='max_length',
                                       truncation=True,
                                       return_tensors = 'pt')
                                      
  

  
  input_ids_ur.append(encoded_dict['input_ids'])
  attn_masks_ur.append(encoded_dict['attention_mask'])
  #print(ex['label'].numpy)
  #we are converting the data into labels
  labels_ur.append(d2.at[ind,'Sentiment'].astype(np.int64))
  
  #convert each python list of tensor to 2D tensor Matrix
input_ids_ur = torch.cat(input_ids_ur,dim=0)
attn_masks_ur = torch.cat(attn_masks_ur,dim=0)

#cast the labels into tensors
labels_ur = torch.tensor(labels_ur)
#print(len(labels_ur))

#combine the trainign inputs to tensorDatasets
dataset = TensorDataset(input_ids_ur,attn_masks_ur, labels_ur)

 #create a 90-10 train validation split
train_size = int(0.9*(len(dataset)))
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(dataset,[train_size, val_size])

batch_size=16

train_dataloader = DataLoader(train_dataset,
                          sampler=RandomSampler(train_dataset),
                          batch_size = batch_size)


validation_dataloader = DataLoader(val_dataset,
                          sampler=RandomSampler(val_dataset),
                          batch_size = batch_size)

xlmr_model = XLMRobertaForSequenceClassification.from_pretrained("xlm-roberta-base",num_labels=3)

print("Loading model to GPU")
#connect to GPU
device = torch.device('cuda')
#report the GPu which is granted 
print('GPU:',torch.cuda.get_device_name(0))
#copy the initial model with weights to GPU
desc = xlmr_model.to(device)
print("Done")

optimizer  = AdamW(xlmr_model.parameters(),
                   lr = 2e-6,# learning rate
                   eps=1e-8 # args.adma_epsilon
                   )

#number of training epochs
epochs = 5
#total no of training steps is [number of batches]*[number of epoches]
total_steps = len(train_dataloader)*epochs

#create the learning rate scheduler 
scheduler  =  get_linear_schedule_with_warmup(optimizer, 
                                              num_warmup_steps = 0,
                                              num_training_steps = total_steps)

progress_bar = tqdm(range(total_steps))

lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=total_steps,
)

seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

training_stats = []

for epoch_i in range(0,epochs):
  #training
  print("Epoch:",epoch_i+1)
  total_train_loss = 0
  xlmr_model.train()
  
  #For each batch of train_data
  for step, batch in enumerate(train_dataloader):
    #progress update 
    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_lables = batch[2].to(device)
    xlmr_model.zero_grad()
    outputs =xlmr_model(b_input_ids,attention_mask = b_input_mask,labels=b_lables)
    loss = outputs.loss
    loss.backward()
    optimizer.step()
    lr_scheduler.step()
    optimizer.zero_grad()
    progress_bar.update(1)
  
  #put the model in evaluation mode
  xlmr_model.eval()
  model_predictions=[]
  true_labels=[]

  for batch in validation_dataloader:
      b_input_ids = batch[0].to(device)
      b_input_mask = batch[1].to(device)
      b_lables = batch[2].to(device)

      with torch.no_grad():
        outputs = xlmr_model(b_input_ids,attention_mask = b_input_mask)
      
      logits = outputs.logits
      logits=logits.detach().cpu().numpy()
      label_ids = b_lables.to('cpu').numpy()
      predictions = np.argmax(logits, axis = -1)
      model_predictions.append(logits)
      true_labels.append(label_ids)
  
  flat_predictions = np.concatenate(model_predictions, axis=0)
  flat_true_labels = np.concatenate(true_labels, axis=0)
  predicted_labels = np.argmax(flat_predictions, axis=1).flatten()
  accuracy = (predicted_labels==flat_true_labels).mean()
  
  print("Epoch: ", epochs)
  print('XLMR - validation accuracy ', accuracy)
  print("------------------------------------ ")
# Out:
# Encoding all Examples in the dataset
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9f1e68ee5de2> in <module>()
#       5 print("Encoding all Examples in the dataset \n" )
#       6
# ----> 7 for ind in d2.index:
#       8   text = d2.Text[ind]
#       9   #convert sentence pairs to input ids, with attention masks
#
# NameError: name 'd2' is not defined

# %% [markdown]
# ## Evaluating the trained Model

# %%
xlmr_model.eval()
model_predictions=[]
true_labels=[]
for batch in validation_dataloader:

    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_lables = batch[2].to(device)

    with torch.no_grad():
      outputs = xlmr_model(b_input_ids,attention_mask = b_input_mask)
    logits = outputs.logits
    logits=logits.detach().cpu().numpy()
    label_ids = b_lables.to('cpu').numpy()
    predictions = np.argmax(logits, axis = -1)
    #print(b_lables)
    #print(predictions)
    #print("\n -------------------------- \n")
    model_predictions.append(logits)
    true_labels.append(label_ids)

# %%
#combine the results across all batches
#predictions
flat_predictions = np.concatenate(model_predictions, axis=0)
flat_true_labels = np.concatenate(true_labels, axis=0)

##for sample pick the label
predicted_labels = np.argmax(flat_predictions, axis=1).flatten()

# %%
# the number of correct predictions to get our accuracy
accuracy = (predicted_labels==flat_true_labels).mean()
print('XLMR- prediction accuracy',accuracy)
# Out:
# XLMR- prediction accuracy 0.6729222520107239

# %% [markdown]
# ## 2. Second run:
#     - Hyperparameters:
#         - max_length = 50
#         - epochs = 15
#         - batch_size = 16

# %%
labels_ur = []
input_ids_ur = []
attn_masks_ur= []

print("Encoding all Examples in the dataset \n" )

for ind in d2.index:
  text = d2.Text[ind]
  #convert sentence pairs to input ids, with attention masks
  
  encoded_dict = xlmr_tokenizer.encode_plus(text,max_length = 50,  
                                       padding='max_length',
                                       truncation=True,
                                       return_tensors = 'pt')
                                      
  

  
  input_ids_ur.append(encoded_dict['input_ids'])
  attn_masks_ur.append(encoded_dict['attention_mask'])
  #print(ex['label'].numpy)
  #we are converting the data into labels
  labels_ur.append(d2.at[ind,'Sentiment'].astype(np.int64))
  
  #convert each python list of tensor to 2D tensor Matrix
input_ids_ur = torch.cat(input_ids_ur,dim=0)
attn_masks_ur = torch.cat(attn_masks_ur,dim=0)

#cast the labels into tensors
labels_ur = torch.tensor(labels_ur)
#print(len(labels_ur))

#combine the trainign inputs to tensorDatasets
dataset = TensorDataset(input_ids_ur,attn_masks_ur, labels_ur)

 #create a 90-10 train validation split
train_size = int(0.9*(len(dataset)))
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(dataset,[train_size, val_size])

batch_size=16

train_dataloader = DataLoader(train_dataset,
                          sampler=RandomSampler(train_dataset),
                          batch_size = batch_size)


validation_dataloader = DataLoader(val_dataset,
                          sampler=RandomSampler(val_dataset),
                          batch_size = batch_size)

xlmr_model = XLMRobertaForSequenceClassification.from_pretrained("xlm-roberta-base",num_labels=3)

print("Loading model to GPU")
#connect to GPU
device = torch.device('cuda')
#report the GPu which is granted 
print('GPU:',torch.cuda.get_device_name(0))
#copy the initial model with weights to GPU
desc = xlmr_model.to(device)
print("Done")

optimizer  = AdamW(xlmr_model.parameters(),
                   lr = 2e-6,# learning rate
                   eps=1e-8 # args.adma_epsilon
                   )

#number of training epochs
epochs = 15
#total no of training steps is [number of batches]*[number of epoches]
total_steps = len(train_dataloader)*epochs

#create the learning rate scheduler 
scheduler  =  get_linear_schedule_with_warmup(optimizer, 
                                              num_warmup_steps = 0,
                                              num_training_steps = total_steps)

progress_bar = tqdm(range(total_steps))

lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=total_steps,
)

seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

training_stats = []

for epoch_i in range(0,epochs):
  #training
  print("Epoch:",epoch_i+1)
  total_train_loss = 0
  xlmr_model.train()
  
  #For each batch of train_data
  for step, batch in enumerate(train_dataloader):
    #progress update 
    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_lables = batch[2].to(device)
    xlmr_model.zero_grad()
    outputs =xlmr_model(b_input_ids,attention_mask = b_input_mask,labels=b_lables)
    loss = outputs.loss
    loss.backward()
    optimizer.step()
    lr_scheduler.step()
    optimizer.zero_grad()
    progress_bar.update(1)
  
  #put the model in evaluation mode
  xlmr_model.eval()
  model_predictions=[]
  true_labels=[]

  for batch in validation_dataloader:
      b_input_ids = batch[0].to(device)
      b_input_mask = batch[1].to(device)
      b_lables = batch[2].to(device)

      with torch.no_grad():
        outputs = xlmr_model(b_input_ids,attention_mask = b_input_mask)
      
      logits = outputs.logits
      logits=logits.detach().cpu().numpy()
      label_ids = b_lables.to('cpu').numpy()
      predictions = np.argmax(logits, axis = -1)
      model_predictions.append(logits)
      true_labels.append(label_ids)
  
  flat_predictions = np.concatenate(model_predictions, axis=0)
  flat_true_labels = np.concatenate(true_labels, axis=0)
  predicted_labels = np.argmax(flat_predictions, axis=1).flatten()
  accuracy = (predicted_labels==flat_true_labels).mean()
  
  print("Epoch: ", epochs)
  print('XLMR - validation accuracy ', accuracy)
  print("------------------------------------ ")
# Out:
# Encoding all Examples in the dataset
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['lm_head.dense.weight', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading model to GPU
# GPU: Tesla T4
# Done
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
#   0%|          | 0/3150 [00:00<?, ?it/s]
# Epoch: 1
# Epoch:  15
# XLMR - validation accuracy  0.5898123324396782
# ------------------------------------
# Epoch: 2
# Epoch:  15
# XLMR - validation accuracy  0.6434316353887399
# ------------------------------------
# Epoch: 3
# Epoch:  15
# XLMR - validation accuracy  0.6997319034852547
# ------------------------------------
# Epoch: 4
# Epoch:  15
# XLMR - validation accuracy  0.7345844504021448
# ------------------------------------
# Epoch: 5
# Epoch:  15
# XLMR - validation accuracy  0.7319034852546917
# ------------------------------------
# Epoch: 6
# Epoch:  15
# XLMR - validation accuracy  0.7238605898123325
# ------------------------------------
# Epoch: 7
# Epoch:  15
# XLMR - validation accuracy  0.7640750670241286
# ------------------------------------
# Epoch: 8
# Epoch:  15
# XLMR - validation accuracy  0.7587131367292225
# ------------------------------------
# Epoch: 9
# Epoch:  15
# XLMR - validation accuracy  0.7694369973190348
# ------------------------------------
# Epoch: 10
# Epoch:  15
# XLMR - validation accuracy  0.7774798927613941
# ------------------------------------
# Epoch: 11
# Epoch:  15
# XLMR - validation accuracy  0.774798927613941
# ------------------------------------
# Epoch: 12
# Epoch:  15
# XLMR - validation accuracy  0.7774798927613941
# ------------------------------------
# Epoch: 13
# Epoch:  15
# XLMR - validation accuracy  0.774798927613941
# ------------------------------------
# Epoch: 14
# Epoch:  15
# XLMR - validation accuracy  0.774798927613941
# ------------------------------------
# Epoch: 15
# Epoch:  15
# XLMR - validation accuracy  0.7721179624664879
# ------------------------------------

# %% [markdown]
# ## Evaluating the trained Model

# %%
xlmr_model.eval()
model_predictions=[]
true_labels=[]
for batch in validation_dataloader:

    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_lables = batch[2].to(device)

    with torch.no_grad():
      outputs = xlmr_model(b_input_ids,attention_mask = b_input_mask)
    logits = outputs.logits
    logits=logits.detach().cpu().numpy()
    label_ids = b_lables.to('cpu').numpy()
    predictions = np.argmax(logits, axis = -1)
    #print(b_lables)
    #print(predictions)
    #print("\n -------------------------- \n")
    model_predictions.append(logits)
    true_labels.append(label_ids)

# %%
#combine the results across all batches
#predictions
flat_predictions = np.concatenate(model_predictions, axis=0)
flat_true_labels = np.concatenate(true_labels, axis=0)

##for sample pick the label
predicted_labels = np.argmax(flat_predictions, axis=1).flatten()

# %%
# the number of correct predictions to get our accuracy
accuracy = (predicted_labels==flat_true_labels).mean()
print('XLMR- prediction accuracy',accuracy)
# Out:
# XLMR- prediction accuracy 0.7721179624664879

# %% [markdown]
# ## 3. Third run:
#     - Hyperparameters:
#         - max_length = 80
#         - epochs = 30
#         - batch_size = 32

# %%
labels_ur = []
input_ids_ur = []
attn_masks_ur= []

print("Encoding all Examples in the dataset \n" )

for ind in d2.index:
  text = d2.Text[ind]
  #convert sentence pairs to input ids, with attention masks
  
  encoded_dict = xlmr_tokenizer.encode_plus(text,max_length = 80,  
                                       padding='max_length',
                                       truncation=True,
                                       return_tensors = 'pt')
                                      
  

  
  input_ids_ur.append(encoded_dict['input_ids'])
  attn_masks_ur.append(encoded_dict['attention_mask'])
  #print(ex['label'].numpy)
  #we are converting the data into labels
  labels_ur.append(d2.at[ind,'Sentiment'].astype(np.int64))
  
  #convert each python list of tensor to 2D tensor Matrix
input_ids_ur = torch.cat(input_ids_ur,dim=0)
attn_masks_ur = torch.cat(attn_masks_ur,dim=0)

#cast the labels into tensors
labels_ur = torch.tensor(labels_ur)
#print(len(labels_ur))

#combine the trainign inputs to tensorDatasets
dataset = TensorDataset(input_ids_ur,attn_masks_ur, labels_ur)

 #create a 90-10 train validation split
train_size = int(0.9*(len(dataset)))
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(dataset,[train_size, val_size])

batch_size=32

train_dataloader = DataLoader(train_dataset,
                          sampler=RandomSampler(train_dataset),
                          batch_size = batch_size)


validation_dataloader = DataLoader(val_dataset,
                          sampler=RandomSampler(val_dataset),
                          batch_size = batch_size)

xlmr_model = XLMRobertaForSequenceClassification.from_pretrained("xlm-roberta-base",num_labels=3)

print("Loading model to GPU")
#connect to GPU
device = torch.device('cuda')
#report the GPu which is granted 
print('GPU:',torch.cuda.get_device_name(0))
#copy the initial model with weights to GPU
desc = xlmr_model.to(device)
print("Done")

optimizer  = AdamW(xlmr_model.parameters(),
                   lr = 2e-6,# learning rate
                   eps=1e-8 # args.adma_epsilon
                   )

#number of training epochs
epochs = 30
#total no of training steps is [number of batches]*[number of epoches]
total_steps = len(train_dataloader)*epochs

#create the learning rate scheduler 
scheduler  =  get_linear_schedule_with_warmup(optimizer, 
                                              num_warmup_steps = 0,
                                              num_training_steps = total_steps)

progress_bar = tqdm(range(total_steps))

lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=total_steps,
)

seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

training_stats = []

for epoch_i in range(0,epochs):
  #training
  print("Epoch:",epoch_i+1)
  total_train_loss = 0
  xlmr_model.train()
  
  #For each batch of train_data
  for step, batch in enumerate(train_dataloader):
    #progress update 
    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_lables = batch[2].to(device)
    xlmr_model.zero_grad()
    outputs =xlmr_model(b_input_ids,attention_mask = b_input_mask,labels=b_lables)
    loss = outputs.loss
    loss.backward()
    optimizer.step()
    lr_scheduler.step()
    optimizer.zero_grad()
    progress_bar.update(1)
  
  #put the model in evaluation mode
  xlmr_model.eval()
  model_predictions=[]
  true_labels=[]

  for batch in validation_dataloader:
      b_input_ids = batch[0].to(device)
      b_input_mask = batch[1].to(device)
      b_lables = batch[2].to(device)

      with torch.no_grad():
        outputs = xlmr_model(b_input_ids,attention_mask = b_input_mask)
      
      logits = outputs.logits
      logits=logits.detach().cpu().numpy()
      label_ids = b_lables.to('cpu').numpy()
      predictions = np.argmax(logits, axis = -1)
      model_predictions.append(logits)
      true_labels.append(label_ids)
  
  flat_predictions = np.concatenate(model_predictions, axis=0)
  flat_true_labels = np.concatenate(true_labels, axis=0)
  predicted_labels = np.argmax(flat_predictions, axis=1).flatten()
  accuracy = (predicted_labels==flat_true_labels).mean()
  
  print("Epoch: ", epochs)
  print('XLMR - validation accuracy ', accuracy)
  print("------------------------------------ ")
# Out:
# Encoding all Examples in the dataset
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['lm_head.dense.weight', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading model to GPU
# GPU: Tesla T4
# Done
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
#   0%|          | 0/3150 [00:00<?, ?it/s]
# Epoch: 1
# Epoch:  30
# XLMR - validation accuracy  0.546916890080429
# ------------------------------------
# Epoch: 2
# Epoch:  30
# XLMR - validation accuracy  0.6434316353887399
# ------------------------------------
# Epoch: 3
# Epoch:  30
# XLMR - validation accuracy  0.7131367292225201
# ------------------------------------
# Epoch: 4
# Epoch:  30
# XLMR - validation accuracy  0.7238605898123325
# ------------------------------------
# Epoch: 5
# Epoch:  30
# XLMR - validation accuracy  0.7319034852546917
# ------------------------------------
# Epoch: 6
# Epoch:  30
# XLMR - validation accuracy  0.7426273458445041
# ------------------------------------
# Epoch: 7
# Epoch:  30
# XLMR - validation accuracy  0.7479892761394102
# ------------------------------------
# Epoch: 8
# Epoch:  30
# XLMR - validation accuracy  0.7426273458445041
# ------------------------------------
# Epoch: 9
# Epoch:  30
# XLMR - validation accuracy  0.7560321715817694
# ------------------------------------
# Epoch: 10
# Epoch:  30
# XLMR - validation accuracy  0.7721179624664879
# ------------------------------------
# Epoch: 11
# Epoch:  30
# XLMR - validation accuracy  0.7587131367292225
# ------------------------------------
# Epoch: 12
# Epoch:  30
# XLMR - validation accuracy  0.7613941018766756
# ------------------------------------
# Epoch: 13
# Epoch:  30
# XLMR - validation accuracy  0.7774798927613941
# ------------------------------------
# Epoch: 14
# Epoch:  30
# XLMR - validation accuracy  0.7801608579088471
# ------------------------------------
# Epoch: 15
# Epoch:  30
# XLMR - validation accuracy  0.7828418230563002
# ------------------------------------
# Epoch: 16
# Epoch:  30
# XLMR - validation accuracy  0.7694369973190348
# ------------------------------------
# Epoch: 17
# Epoch:  30
# XLMR - validation accuracy  0.7801608579088471
# ------------------------------------
# Epoch: 18
# Epoch:  30
# XLMR - validation accuracy  0.7774798927613941
# ------------------------------------
# Epoch: 19
# Epoch:  30
# XLMR - validation accuracy  0.7801608579088471
# ------------------------------------
# Epoch: 20
# Epoch:  30
# XLMR - validation accuracy  0.7801608579088471
# ------------------------------------
# Epoch: 21
# Epoch:  30
# XLMR - validation accuracy  0.7721179624664879
# ------------------------------------
# Epoch: 22
# Epoch:  30
# XLMR - validation accuracy  0.774798927613941
# ------------------------------------
# Epoch: 23
# Epoch:  30
# XLMR - validation accuracy  0.7774798927613941
# ------------------------------------
# Epoch: 24
# Epoch:  30
# XLMR - validation accuracy  0.7721179624664879
# ------------------------------------
# Epoch: 25
# Epoch:  30
# XLMR - validation accuracy  0.7774798927613941
# ------------------------------------
# Epoch: 26
# Epoch:  30
# XLMR - validation accuracy  0.7774798927613941
# ------------------------------------
# Epoch: 27
# Epoch:  30
# XLMR - validation accuracy  0.7721179624664879
# ------------------------------------
# Epoch: 28
# Epoch:  30
# XLMR - validation accuracy  0.7721179624664879
# ------------------------------------
# Epoch: 29
# Epoch:  30
# XLMR - validation accuracy  0.7721179624664879
# ------------------------------------
# Epoch: 30
# Epoch:  30
# XLMR - validation accuracy  0.7721179624664879
# ------------------------------------

# %% [markdown]
# ## Evaluating the trained Model

# %%
xlmr_model.eval()
model_predictions=[]
true_labels=[]
for batch in validation_dataloader:

    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_lables = batch[2].to(device)

    with torch.no_grad():
      outputs = xlmr_model(b_input_ids,attention_mask = b_input_mask)
    logits = outputs.logits
    logits=logits.detach().cpu().numpy()
    label_ids = b_lables.to('cpu').numpy()
    predictions = np.argmax(logits, axis = -1)
    #print(b_lables)
    #print(predictions)
    #print("\n -------------------------- \n")
    model_predictions.append(logits)
    true_labels.append(label_ids)

# %%
#combine the results across all batches
#predictions
flat_predictions = np.concatenate(model_predictions, axis=0)
flat_true_labels = np.concatenate(true_labels, axis=0)

##for sample pick the label
predicted_labels = np.argmax(flat_predictions, axis=1).flatten()

# %%
# the number of correct predictions to get our accuracy
accuracy = (predicted_labels==flat_true_labels).mean()
print('XLMR- prediction accuracy',accuracy)
# Out:
# XLMR- prediction accuracy 0.7721179624664879

# %% [markdown]
# ## 4. Fourth run:
#     - Hyperparameters:
#         - max_length = 40
#         - epochs = 30
#         - batch_size = 32

# %%
labels_ur = []
input_ids_ur = []
attn_masks_ur= []

print("Encoding all Examples in the dataset \n" )

for ind in d2.index:
  text = d2.Text[ind]
  #convert sentence pairs to input ids, with attention masks
  
  encoded_dict = xlmr_tokenizer.encode_plus(text,max_length = 30,  
                                       padding='max_length',
                                       truncation=True,
                                       return_tensors = 'pt')
                                      
  

  
  input_ids_ur.append(encoded_dict['input_ids'])
  attn_masks_ur.append(encoded_dict['attention_mask'])
  #print(ex['label'].numpy)
  #we are converting the data into labels
  labels_ur.append(d2.at[ind,'Sentiment'].astype(np.int64))
  
  #convert each python list of tensor to 2D tensor Matrix
input_ids_ur = torch.cat(input_ids_ur,dim=0)
attn_masks_ur = torch.cat(attn_masks_ur,dim=0)

#cast the labels into tensors
labels_ur = torch.tensor(labels_ur)
#print(len(labels_ur))

#combine the trainign inputs to tensorDatasets
dataset = TensorDataset(input_ids_ur,attn_masks_ur, labels_ur)

 #create a 90-10 train validation split
train_size = int(0.9*(len(dataset)))
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(dataset,[train_size, val_size])

batch_size=32

train_dataloader = DataLoader(train_dataset,
                          sampler=RandomSampler(train_dataset),
                          batch_size = batch_size)


validation_dataloader = DataLoader(val_dataset,
                          sampler=RandomSampler(val_dataset),
                          batch_size = batch_size)

xlmr_model = XLMRobertaForSequenceClassification.from_pretrained("xlm-roberta-base",num_labels=3)

print("Loading model to GPU")
#connect to GPU
device = torch.device('cuda')
#report the GPu which is granted 
print('GPU:',torch.cuda.get_device_name(0))
#copy the initial model with weights to GPU
desc = xlmr_model.to(device)
print("Done")

optimizer  = AdamW(xlmr_model.parameters(),
                   lr = 2e-6,# learning rate
                   eps=1e-8 # args.adma_epsilon
                   )

#number of training epochs
epochs = 30
#total no of training steps is [number of batches]*[number of epoches]
total_steps = len(train_dataloader)*epochs

#create the learning rate scheduler 
scheduler  =  get_linear_schedule_with_warmup(optimizer, 
                                              num_warmup_steps = 0,
                                              num_training_steps = total_steps)

progress_bar = tqdm(range(total_steps))

lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=total_steps,
)

seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

training_stats = []

for epoch_i in range(0,epochs):
  #training
  print("Epoch:",epoch_i+1)
  total_train_loss = 0
  xlmr_model.train()
  
  #For each batch of train_data
  for step, batch in enumerate(train_dataloader):
    #progress update 
    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_lables = batch[2].to(device)
    xlmr_model.zero_grad()
    outputs =xlmr_model(b_input_ids,attention_mask = b_input_mask,labels=b_lables)
    loss = outputs.loss
    loss.backward()
    optimizer.step()
    lr_scheduler.step()
    optimizer.zero_grad()
    progress_bar.update(1)
  
  #put the model in evaluation mode
  xlmr_model.eval()
  model_predictions=[]
  true_labels=[]

  for batch in validation_dataloader:
      b_input_ids = batch[0].to(device)
      b_input_mask = batch[1].to(device)
      b_lables = batch[2].to(device)

      with torch.no_grad():
        outputs = xlmr_model(b_input_ids,attention_mask = b_input_mask)
      
      logits = outputs.logits
      logits=logits.detach().cpu().numpy()
      label_ids = b_lables.to('cpu').numpy()
      predictions = np.argmax(logits, axis = -1)
      model_predictions.append(logits)
      true_labels.append(label_ids)
  
  flat_predictions = np.concatenate(model_predictions, axis=0)
  flat_true_labels = np.concatenate(true_labels, axis=0)
  predicted_labels = np.argmax(flat_predictions, axis=1).flatten()
  accuracy = (predicted_labels==flat_true_labels).mean()
  
  print("Epoch: ", epochs)
  print('XLMR - validation accuracy ', accuracy)
  print("------------------------------------ ")
# Out:
# Encoding all Examples in the dataset
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['lm_head.dense.weight', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading model to GPU
# GPU: Tesla T4
# Done
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
#   0%|          | 0/3150 [00:00<?, ?it/s]
# Epoch: 1
# Epoch:  30
# XLMR - validation accuracy  0.5415549597855228
# ------------------------------------
# Epoch: 2
# Epoch:  30
# XLMR - validation accuracy  0.6353887399463807
# ------------------------------------
# Epoch: 3
# Epoch:  30
# XLMR - validation accuracy  0.6675603217158177
# ------------------------------------
# Epoch: 4
# Epoch:  30
# XLMR - validation accuracy  0.7426273458445041
# ------------------------------------
# Epoch: 5
# Epoch:  30
# XLMR - validation accuracy  0.7828418230563002
# ------------------------------------
# Epoch: 6
# Epoch:  30
# XLMR - validation accuracy  0.7774798927613941
# ------------------------------------
# Epoch: 7
# Epoch:  30
# XLMR - validation accuracy  0.7935656836461126
# ------------------------------------
# Epoch: 8
# Epoch:  30
# XLMR - validation accuracy  0.806970509383378
# ------------------------------------
# Epoch: 9
# Epoch:  30
# XLMR - validation accuracy  0.8042895442359249
# ------------------------------------
# Epoch: 10
# Epoch:  30
# XLMR - validation accuracy  0.7882037533512064
# ------------------------------------
# Epoch: 11
# Epoch:  30
# XLMR - validation accuracy  0.774798927613941
# ------------------------------------
# Epoch: 12
# Epoch:  30
# XLMR - validation accuracy  0.7962466487935657
# ------------------------------------
# Epoch: 13
# Epoch:  30
# XLMR - validation accuracy  0.7828418230563002
# ------------------------------------
# Epoch: 14
# Epoch:  30
# XLMR - validation accuracy  0.7908847184986595
# ------------------------------------
# Epoch: 15
# Epoch:  30
# XLMR - validation accuracy  0.8123324396782842
# ------------------------------------
# Epoch: 16
# Epoch:  30
# XLMR - validation accuracy  0.8096514745308311
# ------------------------------------
# Epoch: 17
# Epoch:  30
# XLMR - validation accuracy  0.8176943699731903
# ------------------------------------
# Epoch: 18
# Epoch:  30
# XLMR - validation accuracy  0.8257372654155496
# ------------------------------------
# Epoch: 19
# Epoch:  30
# XLMR - validation accuracy  0.8257372654155496
# ------------------------------------
# Epoch: 20
# Epoch:  30
# XLMR - validation accuracy  0.8203753351206434
# ------------------------------------
# Epoch: 21
# Epoch:  30
# XLMR - validation accuracy  0.8230563002680965
# ------------------------------------
# Epoch: 22
# Epoch:  30
# XLMR - validation accuracy  0.8230563002680965
# ------------------------------------
# Epoch: 23
# Epoch:  30
# XLMR - validation accuracy  0.8284182305630027
# ------------------------------------
# Epoch: 24
# Epoch:  30
# XLMR - validation accuracy  0.8230563002680965
# ------------------------------------
# Epoch: 25
# Epoch:  30
# XLMR - validation accuracy  0.8150134048257373
# ------------------------------------
# Epoch: 26
# Epoch:  30
# XLMR - validation accuracy  0.8230563002680965
# ------------------------------------
# Epoch: 27
# Epoch:  30
# XLMR - validation accuracy  0.8203753351206434
# ------------------------------------
# Epoch: 28
# Epoch:  30
# XLMR - validation accuracy  0.8230563002680965
# ------------------------------------
# Epoch: 29
# Epoch:  30
# XLMR - validation accuracy  0.8230563002680965
# ------------------------------------
# Epoch: 30
# Epoch:  30
# XLMR - validation accuracy  0.8230563002680965
# ------------------------------------

# %% [markdown]
# ## Evaluating the trained Model

# %%
xlmr_model.eval()
model_predictions=[]
true_labels=[]
for batch in validation_dataloader:

    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_lables = batch[2].to(device)

    with torch.no_grad():
      outputs = xlmr_model(b_input_ids,attention_mask = b_input_mask)
    logits = outputs.logits
    logits=logits.detach().cpu().numpy()
    label_ids = b_lables.to('cpu').numpy()
    predictions = np.argmax(logits, axis = -1)
    #print(b_lables)
    #print(predictions)
    #print("\n -------------------------- \n")
    model_predictions.append(logits)
    true_labels.append(label_ids)

# %%
#combine the results across all batches
#predictions
flat_predictions = np.concatenate(model_predictions, axis=0)
flat_true_labels = np.concatenate(true_labels, axis=0)

##for sample pick the label
predicted_labels = np.argmax(flat_predictions, axis=1).flatten()

# %%
# the number of correct predictions to get our accuracy
accuracy = (predicted_labels==flat_true_labels).mean()
print('XLMR- prediction accuracy',accuracy)
# Out:
# XLMR- prediction accuracy 0.8230563002680965

# %% [markdown]
# ## 5. Fifth run:
#     - Hyperparameters:
#         - max_length = 100
#         - epochs = 30
#         - batch_size = 16

# %%
labels_ur = []
input_ids_ur = []
attn_masks_ur= []

print("Encoding all Examples in the dataset \n" )

for ind in d2.index:
  text = d2.Text[ind]
  #convert sentence pairs to input ids, with attention masks
  
  encoded_dict = xlmr_tokenizer.encode_plus(text,max_length = 100,  
                                       padding='max_length',
                                       truncation=True,
                                       return_tensors = 'pt')
                                      
  

  
  input_ids_ur.append(encoded_dict['input_ids'])
  attn_masks_ur.append(encoded_dict['attention_mask'])
  #print(ex['label'].numpy)
  #we are converting the data into labels
  labels_ur.append(d2.at[ind,'Sentiment'].astype(np.int64))
  
  #convert each python list of tensor to 2D tensor Matrix
input_ids_ur = torch.cat(input_ids_ur,dim=0)
attn_masks_ur = torch.cat(attn_masks_ur,dim=0)

#cast the labels into tensors
labels_ur = torch.tensor(labels_ur)
#print(len(labels_ur))

#combine the trainign inputs to tensorDatasets
dataset = TensorDataset(input_ids_ur,attn_masks_ur, labels_ur)

 #create a 90-10 train validation split
train_size = int(0.9*(len(dataset)))
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(dataset,[train_size, val_size])

batch_size=16

train_dataloader = DataLoader(train_dataset,
                          sampler=RandomSampler(train_dataset),
                          batch_size = batch_size)


validation_dataloader = DataLoader(val_dataset,
                          sampler=RandomSampler(val_dataset),
                          batch_size = batch_size)

xlmr_model = XLMRobertaForSequenceClassification.from_pretrained("xlm-roberta-base",num_labels=3)

print("Loading model to GPU")
#connect to GPU
device = torch.device('cuda')
#report the GPu which is granted 
print('GPU:',torch.cuda.get_device_name(0))
#copy the initial model with weights to GPU
desc = xlmr_model.to(device)
print("Done")

optimizer  = AdamW(xlmr_model.parameters(),
                   lr = 2e-6,# learning rate
                   eps=1e-8 # args.adma_epsilon
                   )

#number of training epochs
epochs = 30
#total no of training steps is [number of batches]*[number of epoches]
total_steps = len(train_dataloader)*epochs

#create the learning rate scheduler 
scheduler  =  get_linear_schedule_with_warmup(optimizer, 
                                              num_warmup_steps = 0,
                                              num_training_steps = total_steps)

progress_bar = tqdm(range(total_steps))

lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=total_steps,
)

seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

training_stats = []

for epoch_i in range(0,epochs):
  #training
  print("Epoch:",epoch_i+1)
  total_train_loss = 0
  xlmr_model.train()
  
  #For each batch of train_data
  for step, batch in enumerate(train_dataloader):
    #progress update 
    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_lables = batch[2].to(device)
    xlmr_model.zero_grad()
    outputs =xlmr_model(b_input_ids,attention_mask = b_input_mask,labels=b_lables)
    loss = outputs.loss
    loss.backward()
    optimizer.step()
    lr_scheduler.step()
    optimizer.zero_grad()
    progress_bar.update(1)
  
  #put the model in evaluation mode
  xlmr_model.eval()
  model_predictions=[]
  true_labels=[]

  for batch in validation_dataloader:
      b_input_ids = batch[0].to(device)
      b_input_mask = batch[1].to(device)
      b_lables = batch[2].to(device)

      with torch.no_grad():
        outputs = xlmr_model(b_input_ids,attention_mask = b_input_mask)
      
      logits = outputs.logits
      logits=logits.detach().cpu().numpy()
      label_ids = b_lables.to('cpu').numpy()
      predictions = np.argmax(logits, axis = -1)
      model_predictions.append(logits)
      true_labels.append(label_ids)
  
  flat_predictions = np.concatenate(model_predictions, axis=0)
  flat_true_labels = np.concatenate(true_labels, axis=0)
  predicted_labels = np.argmax(flat_predictions, axis=1).flatten()
  accuracy = (predicted_labels==flat_true_labels).mean()
  
  print("Epoch: ", epochs)
  print('XLMR - validation accuracy ', accuracy)
  print("------------------------------------ ")
# Out:
# Encoding all Examples in the dataset
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['lm_head.dense.weight', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading model to GPU
# GPU: Tesla T4
# Done
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
#   0%|          | 0/6300 [00:00<?, ?it/s]
# Epoch: 1
# Epoch:  30
# XLMR - validation accuracy  0.5710455764075067
# ------------------------------------
# Epoch: 2
# Epoch:  30
# XLMR - validation accuracy  0.6648793565683646
# ------------------------------------
# Epoch: 3
# Epoch:  30
# XLMR - validation accuracy  0.7560321715817694
# ------------------------------------
# Epoch: 4
# Epoch:  30
# XLMR - validation accuracy  0.7774798927613941
# ------------------------------------
# Epoch: 5
# Epoch:  30
# XLMR - validation accuracy  0.7882037533512064
# ------------------------------------
# Epoch: 6
# Epoch:  30
# XLMR - validation accuracy  0.7882037533512064
# ------------------------------------
# Epoch: 7
# Epoch:  30
# XLMR - validation accuracy  0.7989276139410187
# ------------------------------------
# Epoch: 8
# Epoch:  30
# XLMR - validation accuracy  0.7908847184986595
# ------------------------------------
# Epoch: 9
# Epoch:  30
# XLMR - validation accuracy  0.7935656836461126
# ------------------------------------
# Epoch: 10
# Epoch:  30
# XLMR - validation accuracy  0.7801608579088471
# ------------------------------------
# Epoch: 11
# Epoch:  30
# XLMR - validation accuracy  0.7935656836461126
# ------------------------------------
# Epoch: 12
# Epoch:  30
# XLMR - validation accuracy  0.7935656836461126
# ------------------------------------
# Epoch: 13
# Epoch:  30
# XLMR - validation accuracy  0.806970509383378
# ------------------------------------
# Epoch: 14
# Epoch:  30
# XLMR - validation accuracy  0.8042895442359249
# ------------------------------------
# Epoch: 15
# Epoch:  30
# XLMR - validation accuracy  0.806970509383378
# ------------------------------------
# Epoch: 16
# Epoch:  30
# XLMR - validation accuracy  0.8123324396782842
# ------------------------------------
# Epoch: 17
# Epoch:  30
# XLMR - validation accuracy  0.8150134048257373
# ------------------------------------
# Epoch: 18
# Epoch:  30
# XLMR - validation accuracy  0.8042895442359249
# ------------------------------------
# Epoch: 19
# Epoch:  30
# XLMR - validation accuracy  0.8042895442359249
# ------------------------------------
# Epoch: 20
# Epoch:  30
# XLMR - validation accuracy  0.8096514745308311
# ------------------------------------
# Epoch: 21
# Epoch:  30
# XLMR - validation accuracy  0.8096514745308311
# ------------------------------------
# Epoch: 22
# Epoch:  30
# XLMR - validation accuracy  0.8042895442359249
# ------------------------------------
# Epoch: 23
# Epoch:  30
# XLMR - validation accuracy  0.7989276139410187
# ------------------------------------
# Epoch: 24
# Epoch:  30
# XLMR - validation accuracy  0.7962466487935657
# ------------------------------------
# Epoch: 25
# Epoch:  30
# XLMR - validation accuracy  0.7962466487935657
# ------------------------------------
# Epoch: 26
# Epoch:  30
# XLMR - validation accuracy  0.8016085790884718
# ------------------------------------
# Epoch: 27
# Epoch:  30
# XLMR - validation accuracy  0.806970509383378
# ------------------------------------
# Epoch: 28
# Epoch:  30
# XLMR - validation accuracy  0.806970509383378
# ------------------------------------
# Epoch: 29
# Epoch:  30
# XLMR - validation accuracy  0.8016085790884718
# ------------------------------------
# Epoch: 30
# Epoch:  30
# XLMR - validation accuracy  0.8016085790884718
# ------------------------------------

# %% [markdown]
# ## Evaluating the trained Model

# %%
xlmr_model.eval()
model_predictions=[]
true_labels=[]
for batch in validation_dataloader:

    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_lables = batch[2].to(device)

    with torch.no_grad():
      outputs = xlmr_model(b_input_ids,attention_mask = b_input_mask)
    logits = outputs.logits
    logits=logits.detach().cpu().numpy()
    label_ids = b_lables.to('cpu').numpy()
    predictions = np.argmax(logits, axis = -1)
    #print(b_lables)
    #print(predictions)
    #print("\n -------------------------- \n")
    model_predictions.append(logits)
    true_labels.append(label_ids)

# %%
#combine the results across all batches
#predictions
flat_predictions = np.concatenate(model_predictions, axis=0)
flat_true_labels = np.concatenate(true_labels, axis=0)

##for sample pick the label
predicted_labels = np.argmax(flat_predictions, axis=1).flatten()

# %%
# the number of correct predictions to get our accuracy
accuracy = (predicted_labels==flat_true_labels).mean()
print('XLMR- prediction accuracy',accuracy)
# Out:
# XLMR- prediction accuracy 0.8016085790884718

# %% [markdown]
# ## 6. Sixth run:
#     - Hyperparameters:
#         - max_length = 100
#         - epochs = 30
#         - batch_size = 8

# %%
labels_ur = []
input_ids_ur = []
attn_masks_ur= []

print("Encoding all Examples in the dataset \n" )

for ind in d2.index:
  text = d2.Text[ind]
  #convert sentence pairs to input ids, with attention masks
  
  encoded_dict = xlmr_tokenizer.encode_plus(text,max_length = 100,  
                                       padding='max_length',
                                       truncation=True,
                                       return_tensors = 'pt')
                                      
  

  
  input_ids_ur.append(encoded_dict['input_ids'])
  attn_masks_ur.append(encoded_dict['attention_mask'])
  #print(ex['label'].numpy)
  #we are converting the data into labels
  labels_ur.append(d2.at[ind,'Sentiment'].astype(np.int64))
  
  #convert each python list of tensor to 2D tensor Matrix
input_ids_ur = torch.cat(input_ids_ur,dim=0)
attn_masks_ur = torch.cat(attn_masks_ur,dim=0)

#cast the labels into tensors
labels_ur = torch.tensor(labels_ur)
#print(len(labels_ur))

#combine the trainign inputs to tensorDatasets
dataset = TensorDataset(input_ids_ur,attn_masks_ur, labels_ur)

 #create a 90-10 train validation split
train_size = int(0.9*(len(dataset)))
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(dataset,[train_size, val_size])

batch_size=8

train_dataloader = DataLoader(train_dataset,
                          sampler=RandomSampler(train_dataset),
                          batch_size = batch_size)


validation_dataloader = DataLoader(val_dataset,
                          sampler=RandomSampler(val_dataset),
                          batch_size = batch_size)

xlmr_model = XLMRobertaForSequenceClassification.from_pretrained("xlm-roberta-base",num_labels=3)

print("Loading model to GPU")
#connect to GPU
device = torch.device('cuda')
#report the GPu which is granted 
print('GPU:',torch.cuda.get_device_name(0))
#copy the initial model with weights to GPU
desc = xlmr_model.to(device)
print("Done")

optimizer  = AdamW(xlmr_model.parameters(),
                   lr = 2e-6,# learning rate
                   eps=1e-8 # args.adma_epsilon
                   )

#number of training epochs
epochs = 30
#total no of training steps is [number of batches]*[number of epoches]
total_steps = len(train_dataloader)*epochs

#create the learning rate scheduler 
scheduler  =  get_linear_schedule_with_warmup(optimizer, 
                                              num_warmup_steps = 0,
                                              num_training_steps = total_steps)

progress_bar = tqdm(range(total_steps))

lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=total_steps,
)

seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

training_stats = []

for epoch_i in range(0,epochs):
  #training
  print("Epoch:",epoch_i+1)
  total_train_loss = 0
  xlmr_model.train()
  
  #For each batch of train_data
  for step, batch in enumerate(train_dataloader):
    #progress update 
    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_lables = batch[2].to(device)
    xlmr_model.zero_grad()
    outputs =xlmr_model(b_input_ids,attention_mask = b_input_mask,labels=b_lables)
    loss = outputs.loss
    loss.backward()
    optimizer.step()
    lr_scheduler.step()
    optimizer.zero_grad()
    progress_bar.update(1)
  
  #put the model in evaluation mode
  xlmr_model.eval()
  model_predictions=[]
  true_labels=[]

  for batch in validation_dataloader:
      b_input_ids = batch[0].to(device)
      b_input_mask = batch[1].to(device)
      b_lables = batch[2].to(device)

      with torch.no_grad():
        outputs = xlmr_model(b_input_ids,attention_mask = b_input_mask)
      
      logits = outputs.logits
      logits=logits.detach().cpu().numpy()
      label_ids = b_lables.to('cpu').numpy()
      predictions = np.argmax(logits, axis = -1)
      model_predictions.append(logits)
      true_labels.append(label_ids)
  
  flat_predictions = np.concatenate(model_predictions, axis=0)
  flat_true_labels = np.concatenate(true_labels, axis=0)
  predicted_labels = np.argmax(flat_predictions, axis=1).flatten()
  accuracy = (predicted_labels==flat_true_labels).mean()
  
  print("Epoch: ", epochs)
  print('XLMR - validation accuracy ', accuracy)
  print("------------------------------------ ")
# Out:
# Encoding all Examples in the dataset
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['lm_head.dense.weight', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading model to GPU
# GPU: Tesla T4
# Done
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
#   0%|          | 0/12600 [00:00<?, ?it/s]
# Epoch: 1
# Epoch:  30
# XLMR - validation accuracy  0.6514745308310992
# ------------------------------------
# Epoch: 2
# Epoch:  30
# XLMR - validation accuracy  0.7479892761394102
# ------------------------------------
# Epoch: 3
# Epoch:  30
# XLMR - validation accuracy  0.7801608579088471
# ------------------------------------
# Epoch: 4
# Epoch:  30
# XLMR - validation accuracy  0.7882037533512064
# ------------------------------------
# Epoch: 5
# Epoch:  30
# XLMR - validation accuracy  0.7908847184986595
# ------------------------------------
# Epoch: 6
# Epoch:  30
# XLMR - validation accuracy  0.7962466487935657
# ------------------------------------
# Epoch: 7
# Epoch:  30
# XLMR - validation accuracy  0.7989276139410187
# ------------------------------------
# Epoch: 8
# Epoch:  30
# XLMR - validation accuracy  0.8042895442359249
# ------------------------------------
# Epoch: 9
# Epoch:  30
# XLMR - validation accuracy  0.8042895442359249
# ------------------------------------
# Epoch: 10
# Epoch:  30
# XLMR - validation accuracy  0.8016085790884718
# ------------------------------------
# Epoch: 11
# Epoch:  30
# XLMR - validation accuracy  0.8042895442359249
# ------------------------------------
# Epoch: 12
# Epoch:  30
# XLMR - validation accuracy  0.8123324396782842
# ------------------------------------
# Epoch: 13
# Epoch:  30
# XLMR - validation accuracy  0.8016085790884718
# ------------------------------------
# Epoch: 14
# Epoch:  30
# XLMR - validation accuracy  0.8150134048257373
# ------------------------------------
# Epoch: 15
# Epoch:  30
# XLMR - validation accuracy  0.806970509383378
# ------------------------------------
# Epoch: 16
# Epoch:  30
# XLMR - validation accuracy  0.8203753351206434
# ------------------------------------
# Epoch: 17
# Epoch:  30
# XLMR - validation accuracy  0.8203753351206434
# ------------------------------------
# Epoch: 18
# Epoch:  30
# XLMR - validation accuracy  0.8364611260053619
# ------------------------------------
# Epoch: 19
# Epoch:  30
# XLMR - validation accuracy  0.8176943699731903
# ------------------------------------
# Epoch: 20
# Epoch:  30
# XLMR - validation accuracy  0.8016085790884718
# ------------------------------------
# Epoch: 21
# Epoch:  30
# XLMR - validation accuracy  0.8123324396782842
# ------------------------------------
# Epoch: 22
# Epoch:  30
# XLMR - validation accuracy  0.8096514745308311
# ------------------------------------
# Epoch: 23
# Epoch:  30
# XLMR - validation accuracy  0.8096514745308311
# ------------------------------------
# Epoch: 24
# Epoch:  30
# XLMR - validation accuracy  0.806970509383378
# ------------------------------------
# Epoch: 25
# Epoch:  30
# XLMR - validation accuracy  0.8096514745308311
# ------------------------------------
# Epoch: 26
# Epoch:  30
# XLMR - validation accuracy  0.8096514745308311
# ------------------------------------
# Epoch: 27
# Epoch:  30
# XLMR - validation accuracy  0.8176943699731903
# ------------------------------------
# Epoch: 28
# Epoch:  30
# XLMR - validation accuracy  0.8096514745308311
# ------------------------------------
# Epoch: 29
# Epoch:  30
# XLMR - validation accuracy  0.8150134048257373
# ------------------------------------
# Epoch: 30
# Epoch:  30
# XLMR - validation accuracy  0.8150134048257373
# ------------------------------------

# %% [markdown]
# ## Evaluating the trained Model

# %%
xlmr_model.eval()
model_predictions=[]
true_labels=[]
for batch in validation_dataloader:

    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_lables = batch[2].to(device)

    with torch.no_grad():
      outputs = xlmr_model(b_input_ids,attention_mask = b_input_mask)
    logits = outputs.logits
    logits=logits.detach().cpu().numpy()
    label_ids = b_lables.to('cpu').numpy()
    predictions = np.argmax(logits, axis = -1)
    #print(b_lables)
    #print(predictions)
    #print("\n -------------------------- \n")
    model_predictions.append(logits)
    true_labels.append(label_ids)

# %%
#combine the results across all batches
#predictions
flat_predictions = np.concatenate(model_predictions, axis=0)
flat_true_labels = np.concatenate(true_labels, axis=0)

##for sample pick the label
predicted_labels = np.argmax(flat_predictions, axis=1).flatten()

# %%
# the number of correct predictions to get our accuracy
accuracy = (predicted_labels==flat_true_labels).mean()
print('XLMR- prediction accuracy',accuracy)
# Out:
# XLMR- prediction accuracy 0.8150134048257373

# %% [markdown]
# ## 7. Seventh run:
#     - Hyperparameters:
#         - max_length = 50
#         - epochs = 5
#         - batch_size = 16
#         - learning_rate = 2e-5

# %%
labels_ur = []
input_ids_ur = []
attn_masks_ur= []

print("Encoding all Examples in the dataset \n" )

for ind in d2.index:
  text = d2.Text[ind]
  #convert sentence pairs to input ids, with attention masks
  
  encoded_dict = xlmr_tokenizer.encode_plus(text,max_length = 50,  
                                       padding='max_length',
                                       truncation=True,
                                       return_tensors = 'pt')
                                      
  

  
  input_ids_ur.append(encoded_dict['input_ids'])
  attn_masks_ur.append(encoded_dict['attention_mask'])
  #print(ex['label'].numpy)
  #we are converting the data into labels
  labels_ur.append(d2.at[ind,'Sentiment'].astype(np.int64))
  
  #convert each python list of tensor to 2D tensor Matrix
input_ids_ur = torch.cat(input_ids_ur,dim=0)
attn_masks_ur = torch.cat(attn_masks_ur,dim=0)

#cast the labels into tensors
labels_ur = torch.tensor(labels_ur)
#print(len(labels_ur))

#combine the trainign inputs to tensorDatasets
dataset = TensorDataset(input_ids_ur,attn_masks_ur, labels_ur)

 #create a 90-10 train validation split
train_size = int(0.9*(len(dataset)))
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(dataset,[train_size, val_size])

batch_size=16

train_dataloader = DataLoader(train_dataset,
                          sampler=RandomSampler(train_dataset),
                          batch_size = batch_size)


validation_dataloader = DataLoader(val_dataset,
                          sampler=RandomSampler(val_dataset),
                          batch_size = batch_size)

xlmr_model = XLMRobertaForSequenceClassification.from_pretrained("xlm-roberta-base",num_labels=3)

print("Loading model to GPU")
#connect to GPU
device = torch.device('cuda')
#report the GPu which is granted 
print('GPU:',torch.cuda.get_device_name(0))
#copy the initial model with weights to GPU
desc = xlmr_model.to(device)
print("Done")

optimizer  = AdamW(xlmr_model.parameters(),
                   lr = 2e-5,# learning rate
                   eps=1e-8 # args.adma_epsilon
                   )

#number of training epochs
epochs = 5
#total no of training steps is [number of batches]*[number of epoches]
total_steps = len(train_dataloader)*epochs

#create the learning rate scheduler 
scheduler  =  get_linear_schedule_with_warmup(optimizer, 
                                              num_warmup_steps = 0,
                                              num_training_steps = total_steps)

progress_bar = tqdm(range(total_steps))

lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=total_steps,
)

seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

training_stats = []

for epoch_i in range(0,epochs):
  #training
  print("Epoch:",epoch_i+1)
  total_train_loss = 0
  xlmr_model.train()
  
  #For each batch of train_data
  for step, batch in enumerate(train_dataloader):
    #progress update 
    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_lables = batch[2].to(device)
    xlmr_model.zero_grad()
    outputs =xlmr_model(b_input_ids,attention_mask = b_input_mask,labels=b_lables)
    loss = outputs.loss
    loss.backward()
    optimizer.step()
    lr_scheduler.step()
    optimizer.zero_grad()
    progress_bar.update(1)
  
  #put the model in evaluation mode
  xlmr_model.eval()
  model_predictions=[]
  true_labels=[]

  for batch in validation_dataloader:
      b_input_ids = batch[0].to(device)
      b_input_mask = batch[1].to(device)
      b_lables = batch[2].to(device)

      with torch.no_grad():
        outputs = xlmr_model(b_input_ids,attention_mask = b_input_mask)
      
      logits = outputs.logits
      logits=logits.detach().cpu().numpy()
      label_ids = b_lables.to('cpu').numpy()
      predictions = np.argmax(logits, axis = -1)
      model_predictions.append(logits)
      true_labels.append(label_ids)
  
  flat_predictions = np.concatenate(model_predictions, axis=0)
  flat_true_labels = np.concatenate(true_labels, axis=0)
  predicted_labels = np.argmax(flat_predictions, axis=1).flatten()
  accuracy = (predicted_labels==flat_true_labels).mean()
  
  print("Epoch: ", epochs)
  print('XLMR - validation accuracy ', accuracy)
  print("------------------------------------ ")
# Out:
# Encoding all Examples in the dataset
# Downloading:   0%|          | 0.00/1.04G [00:00<?, ?B/s]
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForSequenceClassification: ['lm_head.bias', 'lm_head.decoder.weight', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading model to GPU
# GPU: Tesla T4
# Done
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
#   0%|          | 0/1050 [00:00<?, ?it/s]
# Epoch: 1
# Epoch:  5
# XLMR - validation accuracy  0.5254691689008043
# ------------------------------------
# Epoch: 2
# Epoch:  5
# XLMR - validation accuracy  0.5254691689008043
# ------------------------------------
# Epoch: 3
# Epoch:  5
# XLMR - validation accuracy  0.5254691689008043
# ------------------------------------
# Epoch: 4
# Epoch:  5
# XLMR - validation accuracy  0.710455764075067
# ------------------------------------
# Epoch: 5
# Epoch:  5
# XLMR - validation accuracy  0.7319034852546917
# ------------------------------------

# %% [markdown]
# ## Evaluating the trained Model

# %%
xlmr_model.eval()
model_predictions=[]
true_labels=[]
for batch in validation_dataloader:

    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_lables = batch[2].to(device)

    with torch.no_grad():
      outputs = xlmr_model(b_input_ids,attention_mask = b_input_mask)
    logits = outputs.logits
    logits=logits.detach().cpu().numpy()
    label_ids = b_lables.to('cpu').numpy()
    predictions = np.argmax(logits, axis = -1)
    #print(b_lables)
    #print(predictions)
    #print("\n -------------------------- \n")
    model_predictions.append(logits)
    true_labels.append(label_ids)

# %%
#combine the results across all batches
#predictions
flat_predictions = np.concatenate(model_predictions, axis=0)
flat_true_labels = np.concatenate(true_labels, axis=0)

##for sample pick the label
predicted_labels = np.argmax(flat_predictions, axis=1).flatten()

# %%
# the number of correct predictions to get our accuracy
accuracy = (predicted_labels==flat_true_labels).mean()
print('XLMR- prediction accuracy',accuracy)
# Out:
# XLMR- prediction accuracy 0.7319034852546917
